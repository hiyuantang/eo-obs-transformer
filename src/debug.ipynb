# %%
from sat_dataset import TFRecordSenegalDataset

# %%
TFRECORD_DIR = 'sat_data/'
CSV_PATH = 'data/senegal_shuffled.csv'
TARGET_BANDS = [
        'BLUE', 'GREEN', 'RED',
        'NIR', 'SWIR1', 'SWIR2',
        'TEMP1',
        'NL'
    ]
IMAGE_SIZE = 224
senegal_dataset = TFRecordSenegalDataset(
                tfrecord_dir=TFRECORD_DIR,
                csv_path=CSV_PATH,
                target_bands=TARGET_BANDS,
                image_size=IMAGE_SIZE 
            )
# Out:
# Loading CSV data from: data/senegal_shuffled.csv
# Scanning for TFRecord files recursively in: sat_data/
# Found 1 TFRecord files.

# %%
senegal_dataset[0]['images_by_year']
# Out:
# {1990: tensor([[[8.8832e-02, 8.3718e-02, 8.6935e-02,  ..., 8.4267e-02,
#            8.4267e-02, 8.4267e-02],
#           [9.2683e-02, 9.1005e-02, 8.9190e-02,  ..., 8.4405e-02,
#            8.4405e-02, 8.7966e-02],
#           [9.4663e-02, 9.2683e-02, 9.1005e-02,  ..., 8.8049e-02,
#            8.8049e-02, 8.7045e-02],
#           ...,
#           [1.2527e-01, 1.2706e-01, 1.2343e-01,  ..., 1.0566e-01,
#            1.0566e-01, 1.1259e-01],
#           [1.2346e-01, 1.2346e-01, 1.1751e-01,  ..., 8.0582e-02,
#            8.0582e-02, 9.4608e-02],
#           [1.1262e-01, 1.1441e-01, 1.0960e-01,  ..., 1.0115e-01,
#            1.0115e-01, 8.8008e-02]],
#
#          [[1.3253e-01, 1.2733e-01, 1.3253e-01,  ..., 1.2981e-01,
#            1.2981e-01, 1.2787e-01],
#           [1.3660e-01, 1.3366e-01, 1.3366e-01,  ..., 1.2812e-01,
#            1.2812e-01, 1.3388e-01],
#           [1.4386e-01, 1.4878e-01, 1.4067e-01,  ..., 1.3763e-01,
#            1.3763e-01, 1.3377e-01],
#           ...,
# ...
